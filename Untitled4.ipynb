# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import random

warnings.simplefilter(action='ignore', category=FutureWarning)

sns.set(style="white", color_codes=True)
sns.set(rc={'figure.figsize':(8,8)})

# %%
data = pd.read_csv('Merch_CB_hack.csv', sep=',', decimal=',', na_values='NaN')

# %%
data
# Out:
#             merchant_name                  day                month  cashback  \
# 0              1С Интерес  2022-01-21 00:00:00  2022-01-01 00:00:00    240.53
# 1              1С Интерес  2022-01-22 00:00:00  2022-01-01 00:00:00    399.21
# 2              1С Интерес  2022-01-23 00:00:00  2022-01-01 00:00:00    385.44
# 3              1С Интерес  2022-01-24 00:00:00  2022-01-01 00:00:00    209.48
# 4              1С Интерес  2022-01-25 00:00:00  2022-01-01 00:00:00    361.80
# ...                   ...                  ...                  ...       ...
# 27537  Яндекс.Еда и Лавка  2023-01-27 00:00:00  2023-01-01 00:00:00  13950.84
# 27538  Яндекс.Еда и Лавка  2023-01-28 00:00:00  2023-01-01 00:00:00  17400.74
# 27539  Яндекс.Еда и Лавка  2023-01-29 00:00:00  2023-01-01 00:00:00  13286.25
# 27540  Яндекс.Еда и Лавка  2023-01-30 00:00:00  2023-01-01 00:00:00   8075.79
# 27541  Яндекс.Еда и Лавка  2023-01-31 00:00:00  2023-01-01 00:00:00   8169.34
#
#       bad_line
# 0          NaN
# ...

# %%
data['merchant_name'].value_counts()
# Out:
# merchant_name
# Яндекс.Такси       334
# Яндекс Такси       334
# Перекрёсток        309
# Delta Sirius       282
# IVI                258
#                   ...
# Магнит косметик      1
# Л'Этуаль             1
# Ситилинк             1
# COLINS               1
# Улыбка радуги        1
# Name: count, Length: 558, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27542 entries, 0 to 27541
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   merchant_name  27542 non-null  object
#  1   day            27499 non-null  object
#  2   month          27499 non-null  object
#  3   cashback       27499 non-null  object
#  4   bad_line       217 non-null    object
# dtypes: object(5)
# memory usage: 1.1+ MB

# %%
bad_data = data[data['bad_line'].isnull() == False]
bad_data.

# %%
# Out:
# (217, 5)

# %%
for i in range(bad_data.shape[0]):
    print(bad_data.iloc[i])
    print()
# Out:
# merchant_name                  Reima
# day                 интернет-магазин
# month            2022-01-01 00:00:00
# cashback         2022-01-01 00:00:00
# bad_line                       81.70
# Name: 896, dtype: object
#
# merchant_name                  Reima
# day                 интернет-магазин
# month            2022-01-02 00:00:00
# cashback         2022-01-01 00:00:00
# bad_line                       33.75
# Name: 897, dtype: object
#
# merchant_name                  Reima
# day                 интернет-магазин
# month            2022-01-03 00:00:00
# cashback         2022-01-01 00:00:00
# bad_line                      369.61
# Name: 898, dtype: object
#
# merchant_name                  Reima
# day                 интернет-магазин
# month            2022-01-04 00:00:00
# cashback         2022-01-01 00:00:00
# bad_line                      378.62
# Name: 899, dtype: object
#
# merchant_name                  Reima
# day                 интернет-магазин
# ...
